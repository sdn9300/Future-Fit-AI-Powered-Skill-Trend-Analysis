# %% [markdown]
# # 04 - Visualization & Storytelling
#
# This notebook turns the Phase 3 findings into five publication-ready charts and saves them under `assets/charts/`.
#
# The visuals reflect the actual data shape: the primary dataset is annual, balanced, and centered on 11 recurring skills, so the charts emphasize concentration, trend direction, co-occurrence, and subtle experience-level differences.

# %% [markdown]
# ## Chart Plan
#
# 1. Top skill ranking
# 2. Annual trend lines for the biggest risers and decliners
# 3. Skill co-occurrence heatmap
# 4. Skill mix by experience level
# 5. Skill word cloud

# %%
from pathlib import Path
from IPython.display import Image, display

from src.phase4_visualization import build_all_charts

summary = build_all_charts()
summary

# %% [markdown]
# ### Chart 1 - Top skill ranking
#
# The ranking shows that no single skill overwhelms the dataset; instead, the market is concentrated around a stable core of cloud, ML, and programming skills.

# %%
display(Image(filename='assets/charts/01_top_skills_ranking.png'))

# %% [markdown]
# ### Chart 2 - Annual trend lines
#
# The annual trend chart highlights small but real share gains for Computer Vision, Scikit-Learn, TensorFlow, and the major cloud tools.

# %%
display(Image(filename='assets/charts/02_skill_trends_annual.png'))

# %% [markdown]
# ### Chart 3 - Co-occurrence heatmap
#
# The heatmap makes it obvious that the same handful of skills are repeatedly requested together, which supports a bundled job-skill profile rather than isolated single-skill roles.

# %%
display(Image(filename='assets/charts/03_skill_cooccurrence_heatmap.png'))

# %% [markdown]
# ### Chart 4 - Experience-level mix
#
# The experience-level view is intentionally subtle: the same core skills appear across entry, mid, and senior roles, with only small shifts in emphasis.

# %%
display(Image(filename='assets/charts/04_skill_mix_by_experience.png'))

# %% [markdown]
# ### Chart 5 - Skill word cloud
#
# The word cloud is a compact summary view for presentations and portfolio pages. It is not a substitute for the ranked charts, but it is a useful visual recap.

# %%
display(Image(filename='assets/charts/05_skill_wordcloud.png'))

# %% [markdown]
# ## Phase 4 takeaway
#
# The export set is now ready for the next phase: polished chart assets exist on disk, the visuals align with the cleaned data, and the notebook documents the finding behind each chart.
